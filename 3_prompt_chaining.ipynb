# %%
from langgraph.graph import StateGraph , START , END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(model = "models/gemini-2.0-flash" ,google_api_key="AIzaSyBudd3Ynuiz2JeLQnITpMZWZ2DHGk8pSDw")

# %%
class BlogState(TypedDict):
    title:str
    outline:str
    content:str

# %%
def create_outline(state:BlogState) ->BlogState:
    
    title = state['title']

    prompt = f"Genrate a Detailed Outline for a blog on the topic : {title}"

    outline = model.invoke(prompt).content
    state['outline'] = outline
    return state

# %%
def create_content(state:BlogState)->BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f"write a Detailed Blog on the Title - {title} using the Following Outline \n {outline}"

    content = model.invoke(prompt).content
    state['content'] = content
    return state

# %%
graph = StateGraph(BlogState)

graph.add_node("create_outline" , create_outline)
graph.add_node("create_content" , create_content)

graph.add_edge(START , 'create_outline')
graph.add_edge('create_outline' , 'create_content')
graph.add_edge('create_content' , END)

workflow = graph.compile()

# %%
initial_state  =BlogState(title="Rize of AI in India")
final_state =workflow.invoke(initial_state)
print(final_state)
# Out:
# {'title': 'Rize of AI in India', 'outline': '## Blog Outline: The Rise of AI in India: Opportunities, Challenges, and the Future\n\n**I. Introduction (Hook & Context Setting)**\n\n*   **A. Hook:**  Start with a compelling statistic or anecdote about AI adoption in India. (e.g., "India\'s AI market is projected to reach \\$XX billion by 20XX, signaling a massive technological shift...")\n*   **B. Briefly Define AI:**  A concise and accessible explanation of what Artificial Intelligence is, avoiding overly technical jargon.\n*   **C. Contextualize the Rise:** Briefly explain *why* AI is gaining traction in India now. (e.g., Increased internet penetration, availability of data, government initiatives, etc.)\n*   **D. Thesis Statement:**  Clearly state the blog\'s main argument.  For example: "India is poised to become a global AI hub, driven by its demographic dividend, burgeoning tech sector, and proactive government policies, but faces challenges related to infrastructure, skills gap,
# ...

# %%
print(final_state['outline'])
# Out:
# ## Blog Outline: The Rise of AI in India: Opportunities, Challenges, and the Future
#
# **I. Introduction (Hook & Context Setting)**
#
# *   **A. Hook:**  Start with a compelling statistic or anecdote about AI adoption in India. (e.g., "India's AI market is projected to reach \$XX billion by 20XX, signaling a massive technological shift...")
# *   **B. Briefly Define AI:**  A concise and accessible explanation of what Artificial Intelligence is, avoiding overly technical jargon.
# *   **C. Contextualize the Rise:** Briefly explain *why* AI is gaining traction in India now. (e.g., Increased internet penetration, availability of data, government initiatives, etc.)
# ...

# %%
print(final_state['content'])
# Out:
# ## The Rise of AI in India: Opportunities, Challenges, and the Future
#
# **I. Introduction: India's AI Awakening**
#
# *   **A. Hook:** India's AI market is projected to reach a staggering \$15.7 billion by 2026, a figure that underscores the profound technological shift sweeping across the nation. From smart agriculture to personalized healthcare, Artificial Intelligence (AI) is rapidly transforming industries and reshaping the Indian landscape.
# *   **B. Briefly Define AI:** Artificial Intelligence, at its core, refers to the ability of machines to perform tasks that typically require human intelligence, such as learning, problem-solving, and decision-making. It encompasses a range of technologies, including machine learning, natural language processing, and computer vision.
# ...
